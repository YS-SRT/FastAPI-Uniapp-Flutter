# %%
# add upper dir in the path, recognize model name
from utils import add_upper_dir_in_path
add_upper_dir_in_path()

# %%
# load dataset, model
from aitrain.classifier_torch import HWDataset, TorchClassifier

# %%
# test dataset
dataset = HWDataset()
dataset.plot_image(2)

# %%
# train model
classifier = TorchClassifier()
classifier.train(3)
classifier.save_model_state()
# Out:
# start train model...

# %%
# verify model
classifier.random_eval_model()

# %%
from utils import add_upper_dir_in_path
add_upper_dir_in_path()

# %%
from aitrain.classifier_tensorflow import TFDataset, TFClassifier

# %%
data = TFDataset(100)
data.plot_image(5)

# %%
classifier = TFClassifier(data)
classifier.train(3)
classifier.save_model_weights()
# Out:
# Epoch 1/3
# 150/150 - 82s - loss: 1.0950 - accuracy: 0.6423 - 82s/epoch - 548ms/step
# Epoch 2/3
# 150/150 - 93s - loss: 0.2236 - accuracy: 0.9259 - 93s/epoch - 623ms/step
# Epoch 3/3
# 150/150 - 101s - loss: 0.1030 - accuracy: 0.9683 - 101s/epoch - 671ms/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, None, None, None   0
#                              )
#
#  conv2d (Conv2D)             (None, None, None, 32)    320
#
#  max_pooling2d (MaxPooling2  (None, None, None, 32)    0
#  D)
#
#  conv2d_1 (Conv2D)           (None, None, None, 64)    18496
#
#  max_pooling2d_1 (MaxPoolin  (None, None, None, 64)    0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, None, None, 128)   73856
#
#  max_pooling2d_2 (MaxPoolin  (None, None, None, 128)   0
#  g2D)
#
#  flatten (Flatten)           (None, None)              0
#
#  dense (Dense)               (None, 1024)              8389632
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 256)               262400
#
#  dense_2 (Dense)             (None, 15)                3855
#
# =================================================================
# Total params: 8748559 (33.37 MB)
# Trainable params: 8748559 (33.37 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
classifier.random_eval_model()
# Out:
# 1/1 [==============================] - 0s 28ms/step
